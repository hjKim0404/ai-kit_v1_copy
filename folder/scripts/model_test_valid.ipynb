# %% [markdown]
# ## 1. 필요한 패키지들을 불러옵니다.

# %%
import os
BASE_PATH = os.path.dirname(os.getcwd())
os.chdir(BASE_PATH)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import load_model

# %%
from utils.helper import images_cropper, glob_all_files, paths2numpy
from utils.helper import draw_rectangles, show_images

# %%
from tensorflow.keras.optimizers import Adam
from utils.datagenerator_now import TightFaceProvider_Wally_Girl

# %%
wally_folder = './valid_data/train_imgs/waly_face/'
girl_folder = "./valid_data/train_imgs/girl_face/"
bg_folder = './valid_data/train_imgs/back_imgs/'

#from utils.helper_imaug import random_imaug
#fg_imgs = paths2numpy(glob_all_files(fg_folder))
#show_images(random_imaug(fg_imgs))
#tfp = TightFaceProvider(wally_folder, girl_folder, bg_folder, batch_size=64)
tfp = TightFaceProvider(wally_folder, girl_folder, bg_folder, batch_size=64)
# Out:
# Max Height : 26 	 Min Height : 11
# Max Width : 17 	 Min Width : 10
# Max W/H Ratio : 1.0 	 Min Ratio : 0.6111111111111112

# %%
show_images(tfp[4][0], titles=tfp[4][1].tolist())
